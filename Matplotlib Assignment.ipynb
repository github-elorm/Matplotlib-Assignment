# %%
import pandas as pd
iris = pd.read_csv(r"C:\Users\elorm\Downloads\IRIS.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             NaN          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           NaN          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
str(iris)
# Out:
# '     sepal_length  sepal_width  petal_length  petal_width         species\n0             5.1          3.5           1.4          0.2     Iris-setosa\n1             4.9          3.0           1.4          0.2     Iris-setosa\n2             4.7          3.2           1.3          0.2     Iris-setosa\n3             NaN          3.1           1.5          0.2     Iris-setosa\n4             5.0          3.6           1.4          0.2     Iris-setosa\n..            ...          ...           ...          ...             ...\n145           6.7          3.0           5.2          2.3  Iris-virginica\n146           6.3          2.5           5.0          1.9  Iris-virginica\n147           6.5          3.0           5.2          2.0  Iris-virginica\n148           6.2          3.4           5.4          2.3  Iris-virginica\n149           5.9          3.0           NaN          1.8  Iris-virginica\n\n[150 rows x 5 columns]'

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(iris.index, iris.iloc[:, 3])
plt.xlabel("index")
plt.ylabel("petal width")

plt.show()

# %%
plt.scatter(iris.index, iris.iloc[:,0])
plt.xlabel("index")
plt.ylabel("sepal length")
plt.show()

# %%
plt.scatter(iris.index, iris.iloc[:,1])
plt.xlabel("index")
plt.ylabel("sepal width")
plt.show()

# %%
plt.scatter(iris.index, iris.iloc[:,2])
plt.xlabel("index")
plt.ylabel("petal_length")
plt.show()

# %%
plt.boxplot(iris.iloc[:, 3])
plt.show()

# %%
plt.scatter(iris['petal_length'], iris['petal_width'])
plt.xlabel("petal length")
plt.ylabel("petal width")
plt.show()

# %%
plt.scatter(iris['sepal_length'], iris['petal_length'])
plt.xlabel("sepal length")
plt.ylabel("petal length")
plt.show()

# %%
plt.scatter(iris['petal_width'], iris['sepal_width'])
plt.xlabel("petal width")
plt.ylabel("sepal width")
plt.show()

# %%
plt.scatter(iris['petal_length'], iris['sepal_width'])
plt.xlabel("petal length")
plt.ylabel("sepal width")
plt.show()
